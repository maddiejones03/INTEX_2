# %%
import pandas as pd

df = pd.read_csv('donations.csv')

df.head()
# Out:
#    donation_id  supporter_id donation_type donation_date  is_recurring  \
# 0            1            42      Monetary    2025-12-31         False
# 1            2            25          Time    2025-12-02          True
# 2            3            19      Monetary    2024-12-02         False
# 3            4            33      Monetary    2023-09-11         False
# 4            5            24        InKind    2023-11-08          True
#
#    campaign_name   channel_source currency_code   amount  estimated_value  \
# 0            NaN         Campaign           PHP   717.18           717.18
# 1  Year-End Hope            Event           NaN      NaN            35.15
# 2            NaN  PartnerReferral           PHP  1074.65          1074.65
# 3            NaN  PartnerReferral           PHP  1230.56          1230.56
# 4  GivingTuesday      SocialMedia           NaN      NaN          1177.41
#
#   impact_unit                               notes  referral_post_id
# ...

# %%
df['donation_type'].value_counts()
# Out:
# donation_type
# Monetary       234
# InKind          98
# Time            46
# SocialMedia     23
# Skills          19
# Name: count, dtype: int64
